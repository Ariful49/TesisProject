# %%
import csv
import pandas as pd
import numpy as np

# %%
symptoms = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/symptoms.csv", 
                  error_bad_lines=False,sep=',', encoding = 'utf-8')

# %%
symptoms
# Out:
#        subject_id ankleswelling bloated breathlessness confusion depression  \
# 0               3           NaN     NaN            NaN       NaN       True
# 1               8           NaN     NaN            NaN       NaN       True
# 2              11           NaN     NaN            NaN      True        NaN
# 3              12           NaN     NaN            NaN       NaN        NaN
# 4              13           NaN     NaN            NaN       NaN        NaN
# 5              17           NaN     NaN            NaN       NaN       True
# 6              20           NaN     NaN            NaN       NaN       True
# 7              23           NaN     NaN            NaN       NaN        NaN
# 8              24           NaN     NaN            NaN       NaN        NaN
# 9              28           NaN     NaN            NaN       NaN        NaN
# 10             31           NaN     NaN            NaN      True        NaN
# ...

# %%
symptom = symptoms["confusion"]
falsesymptom = symptom.isna().sum()
percentfalsesymptom = falsesymptom / len (symptoms)
percentfalsesymptom
# Out:
# 0.8139283591766168

# %%
truesymptom = len (symptoms) - falsesymptom
percenttruesymptom= truesymptom / len (symptoms)
percenttruesymptom
# Out:
# 0.1860716408233832
