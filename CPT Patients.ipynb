# %%
import csv
import pandas as pd
import numpy as np

# %%
patients = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Patients/patients.csv", 
                  error_bad_lines=False,sep=',', encoding = 'utf-8')

# %%
patients
# Out:
#        subject_id    age age_group gender issmoking isconsumingalcohol  \
# 0               2    0.0      baby      M       NaN                NaN
# 1               5    0.0      baby      M       NaN                NaN
# 2               6   66.0     adult      F       NaN               True
# 3               7    0.0      baby      F       NaN                NaN
# 4               8    0.0      baby      M       NaN                NaN
# 5               9   42.0     adult      M       NaN                NaN
# 6              10    0.0      baby      F       NaN                NaN
# 7              11   50.0     adult      F       NaN                NaN
# 8              12   72.0     adult      M       NaN                NaN
# 9              13   40.0     adult      F       NaN                NaN
# 10             16    0.0      baby      M       NaN                NaN
# 11             18   51.0     adult    NaN       NaN                NaN
# ...

# %%
patient = patients["diabetic"]
falsepatient = patient.isna().sum()
percentfalsepatient= falsepatient / len (patients)
percentfalsepatient
# Out:
# 0.952698271112627

# %%
truepatient = len (patients) - falsepatient
percenttruepatient= truepatient / len (patients)
percenttruepatient
# Out:
# 0.047301728887373086
