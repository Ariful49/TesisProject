# %%
import csv
import pandas as pd
import numpy as np

df1 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/ankleswelling.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df2 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/bloated.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df3 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/breathlessness.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df4 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/confusion.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df5 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/depression.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df6 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/fatigue.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df7 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/lossofappetite.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df8 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/nocturnalcough.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df9 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/orthopnoea.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df10 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/palpitation.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df11 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/paroxysmalnocturnaldyspnoea.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df12 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/reducedexercisetolerance.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df13 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/syncope.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df14 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/tiredness.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df15 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/weightgain.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df16 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/weightloss.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')
df17 = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Symptoms/wheezing.csv", 
                  error_bad_lines=False,sep=';', encoding = 'utf-8')

# %%
dfa = df1.merge(df2, on=["subject_id"], how='outer')

# %%
dfb = dfa.merge(df3, on=["subject_id"], how='outer')

# %%
dfc = dfb.merge(df4, on=["subject_id"], how='outer')

# %%
dfd = dfc.merge(df5, on=["subject_id"], how='outer')

# %%
dfe = dfd.merge(df6, on=["subject_id"], how='outer')

# %%
dff = dfe.merge(df7, on=["subject_id"], how='outer')

# %%
dfg = dff.merge(df8, on=["subject_id"], how='outer')

# %%
dfh = dfg.merge(df9, on=["subject_id"], how='outer')

# %%
dfi = dfh.merge(df10, on=["subject_id"], how='outer')

# %%
dfj = dfi.merge(df11, on=["subject_id"], how='outer')

# %%
dfk = dfj.merge(df12, on=["subject_id"], how='outer')

# %%
dfl = dfk.merge(df13, on=["subject_id"], how='outer')

# %%
dfm = dfl.merge(df14, on=["subject_id"], how='outer')

# %%
dfn = dfm.merge(df15, on=["subject_id"], how='outer')

# %%
dfo = dfn.merge(df16, on=["subject_id"], how='outer')

# %%
dffinal = dfo.merge(df17, on=["subject_id"], how='outer')

# %%
dffinal.to_csv("E:/symptoms.csv",index=False)

# %%
dffinal
# Out:
#         subject_id ankleswelling bloated breathlessness confusion depression  \
# 0                3           NaN     NaN            NaN       NaN       True
# 1                8           NaN     NaN            NaN       NaN       True
# 2               11           NaN     NaN            NaN      True        NaN
# 3               12           NaN     NaN            NaN       NaN        NaN
# 204610          13           NaN     NaN            NaN       NaN        NaN
# 4               17           NaN     NaN            NaN       NaN       True
# 5               20           NaN     NaN            NaN       NaN       True
# 6               23           NaN     NaN            NaN       NaN        NaN
# 207611          24           NaN     NaN            NaN       NaN        NaN
# 92541           28           NaN     NaN            NaN       NaN        NaN
# 7               31           NaN     NaN            NaN      True        NaN
# ...

# %%
# sorting by first name 
dffinal.sort_values("subject_id", inplace = True) 
  
# dropping ALL duplicte values 
dffinal.drop_duplicates(subset ="subject_id", 
                     keep = False, inplace = True)
