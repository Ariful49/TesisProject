# %%
import csv
import pandas as pd
import numpy as np

# %%
signs = pd.read_csv("C:/Users/Ay/OneDrive - Institut Teknologi Sepuluh Nopember/Tesis/Signs/signs.csv", 
                  error_bad_lines=False,sep=',', encoding = 'utf-8')

# %%
signs
# Out:
#        subject_id elevatedjugularvenouspressure hepatojugularreflux  \
# 0               5                           NaN                 NaN
# 1               8                           NaN                 NaN
# 2               9                           NaN                 NaN
# 3              12                           NaN                 NaN
# 4              22                           NaN                 NaN
# 5              25                           NaN                 NaN
# 6              26                           NaN                 NaN
# 7              28                           NaN                 NaN
# 8              30                           NaN                 NaN
# 9              39                           NaN                 NaN
# 10             41                           NaN                 NaN
# 11             45                           NaN                 NaN
# 12             49                           NaN                 NaN
# ...

# %%
sign = signs["tachypnoea"]
falsesign = sign.isna().sum()
percentfalsesign= falsesign / len (signs)
percentfalsesign
# Out:
# 0.9994558316705968

# %%
truesign = len (signs) - falsesign
percenttruesign= truesign / len (signs)
percenttruesign
# Out:
# 0.0005441683294032287
